# %%
import os
import numpy as np
import pandas as pd
import networkx as nx
import torch
from torch_geometric.data import Data
import pickle
import math
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       4 import networkx as nx
#       5 import torch
# ----> 6 from torch_geometric.data import Data
#       7 import pickle
#       8 import math
#
# ModuleNotFoundError: No module named 'torch_geometric'

# %%
def parse_bench_file(file_path):
    """
    Parse BENCH file and convert to NetworkX directed graph
    
    Args:
        file_path: Path to the .bench file
        
    Returns:
        NetworkX DiGraph with gate types as node attributes
    """
    G = nx.DiGraph()
    
    with open(file_path, 'r') as f:
        for line in f:
            line = line.strip()
            
            # Skip comments and empty lines
            if not line or line.startswith('#'):
                continue
                
            if line.startswith('INPUT'):
                # Extract input signal: INPUT(pi00) -> pi00
                signal = line.split('(')[1].split(')')[0]
                G.add_node(signal, gate_type='INPUT', is_primary_input=True)
                
            elif line.startswith('OUTPUT'):
                # Extract output signal: OUTPUT(po0) -> po0
                signal = line.split('(')[1].split(')')[0]
                G.add_node(signal, gate_type='OUTPUT', is_primary_output=True)
                
            elif '=' in line:
                # Parse gate definition: n42 = NOT(pi00) or po0 = AND(n68, n329)
                left, right = line.split('=', 1)
                output_signal = left.strip()
                gate_expr = right.strip()
                
                # Extract gate type and input signals
                gate_type = gate_expr.split('(')[0].strip()
                inputs_str = gate_expr.split('(')[1].split(')')[0]
                input_signals = [s.strip() for s in inputs_str.split(',')]
                
                # Add gate node (if not already added as output)
                if output_signal not in G.nodes():
                    G.add_node(output_signal, 
                              gate_type=gate_type, 
                              is_primary_input=False,
                              is_primary_output=False)
                else:
                    # Update existing node with gate information
                    G.nodes[output_signal]['gate_type'] = gate_type
                
                # Add edges from inputs to this gate
                for input_signal in input_signals:
                    G.add_edge(input_signal, output_signal)
    
    return G

def get_nodes_from_influence_data(influence_df):
    """
    Extract node names from influence DataFrame with proper column handling
    """
    print(f"Analyzing influence DataFrame with columns: {influence_df.columns.tolist()}")
    
    # Look for the Input column (with or without leading space)
    input_columns = ['Input', ' Input', 'input', ' input']
    
    for col in input_columns:
        if col in influence_df.columns:
            nodes = influence_df[col].astype(str).tolist()
            print(f"Found nodes in column '{col}': {nodes[:5]}...")  # Show first 5
            return nodes
    
    print("ERROR: Could not find Input column")
    return []

def map_influence_nodes_to_circuit_nodes(influence_nodes, circuit_graph):
    """
    Map influence file node names (G0, G1, etc.) to circuit node names (pi00, pi01, etc.)
    """
    valid_nodes = []
    node_mapping = {}
    
    for influence_node in influence_nodes:
        # Try different mapping strategies
        circuit_node_candidates = []
        
        if influence_node.startswith('G') and influence_node[1:].isdigit():
            # G0 -> pi00, G1 -> pi01, etc.
            node_num = int(influence_node[1:])
            circuit_node_candidates = [
                f'pi{node_num:02d}',  # pi00, pi01, pi02, etc.
                f'pi{node_num}',      # pi0, pi1, pi2, etc.
                influence_node        # Keep original as fallback
            ]
        else:
            # For other formats, try as-is
            circuit_node_candidates = [influence_node]
        
        # Find which candidate exists in the circuit
        for candidate in circuit_node_candidates:
            if candidate in circuit_graph.nodes():
                valid_nodes.append(candidate)
                node_mapping[influence_node] = candidate
                break
    
    print(f"Mapped {len(valid_nodes)} nodes out of {len(influence_nodes)} influence nodes")
    
    return valid_nodes, node_mapping

def create_hamming_weight_class(hamming_weight, input_count):
    """
    Create classification target based on Hamming weight ratio
    Based on data distribution analysis: 3 classes with natural breakpoints
    """
    try:
        # Calculate ratio using log scale to handle large numbers
        log_hamming = math.log10(hamming_weight) if hamming_weight > 0 else -float('inf')
        log_total_space = input_count * math.log10(2)
        log_ratio = log_hamming - log_total_space
        ratio = 10 ** log_ratio if log_ratio > -float('inf') else 0.0
        
        # Classification based on data distribution analysis
        if ratio < 0.01:
            return 0  # "Ultra-Sparse" - ~85% of data
        elif ratio < 0.06:
            return 1  # "Sparse" - ~10% of data  
        else:
            return 2  # "Dense" - ~5% of data
            
    except (ValueError, OverflowError):
        return 0  # Default to ultra-sparse for problematic cases
    
def create_enhanced_node_features(graph, valid_nodes, influence_df, node_mapping):
    """Fast version focusing on essential features only"""
    gate_type_mapping = {
        'INPUT': 0, 'OUTPUT': 1, 'AND': 2, 'NAND': 3, 
        'OR': 4, 'NOR': 5, 'NOT': 6, 'XOR': 7, 'XNOR': 8
    }
    
    node_features = []
    
    for circuit_node in valid_nodes:
        feature_vector = []
        
        # 1. Gate type (fast)
        gate_type = graph.nodes[circuit_node].get('gate_type', 'UNKNOWN')
        gate_type_onehot = [0] * len(gate_type_mapping)
        if gate_type in gate_type_mapping:
            gate_type_onehot[gate_type_mapping[gate_type]] = 1
        feature_vector.extend(gate_type_onehot)
        
        # 2. Basic structural features (fast)
        in_degree = graph.in_degree(circuit_node)
        out_degree = graph.out_degree(circuit_node)
        feature_vector.extend([in_degree, out_degree])
        
        # 3. Influence value (existing logic)
        influence_value = 0.0
        if circuit_node in node_mapping.values():
            # This is a primary input - get its influence value
            for inf_node, circ_node in node_mapping.items():
                if circ_node == circuit_node:
                    input_col = None
                    for col in ['Input', ' Input', 'input', ' input']:
                        if col in influence_df.columns:
                            input_col = col
                            break
                    
                    if input_col:
                        influence_col = None
                        for col in [' Influence', 'Influence', ' influence', 'influence']:
                            if col in influence_df.columns:
                                influence_col = col
                                break
                        
                        if influence_col:
                            node_rows = influence_df[influence_df[input_col].astype(str) == str(inf_node)]
                            if len(node_rows) > 0:
                                try:
                                    influence_value = float(node_rows[influence_col].values[0])
                                except:
                                    influence_value = 0.0
                    break
        feature_vector.append(influence_value)
        
        # 4. Simple node type indicator
        is_primary_input = 1 if circuit_node in node_mapping.values() else 0
        feature_vector.append(is_primary_input)
        
        node_features.append(feature_vector)
    
    return np.array(node_features, dtype=np.float32)


def prepare_slice_data_classification(circuit_graph, influence_file_path, hamming_weight, slice_label):
    """
    Create PyTorch Geometric Data object for classification
    Includes full circuit context with slice-specific features
    """
    try:
        influence_df = pd.read_csv(influence_file_path)
        print(f"\nProcessing slice {slice_label}")
    except Exception as e:
        print(f"Error reading influence file {influence_file_path}: {e}")
        return None
    
    # Get influence nodes and map to circuit nodes
    influence_nodes = get_nodes_from_influence_data(influence_df)
    if not influence_nodes:
        return None
    
    primary_input_nodes, node_mapping = map_influence_nodes_to_circuit_nodes(influence_nodes, circuit_graph)
    
    if not primary_input_nodes:
        return None
    
    # Include extended context: primary inputs + connected gates
    extended_nodes = set(primary_input_nodes)
    
    # Add immediate successors and their successors for richer context
    for pi_node in primary_input_nodes:
        successors = list(circuit_graph.successors(pi_node))
        extended_nodes.update(successors)
        
        # Add second-hop neighbors (limited to avoid explosion)
        for succ in successors:
            second_hop = list(circuit_graph.successors(succ))
            extended_nodes.update(second_hop[:3])  # Limit to 3 per successor
    
    valid_nodes = list(extended_nodes)
    input_count = len(primary_input_nodes)  # Number of primary inputs in this slice
    
    print(f"Extended to {len(valid_nodes)} nodes (from {len(primary_input_nodes)} primary inputs)")
    
    # Create subgraph with extended node set
    slice_subgraph = circuit_graph.subgraph(valid_nodes).copy()
    print(f"Subgraph has {slice_subgraph.number_of_edges()} edges")
    
    # Create classification target
    class_label = create_hamming_weight_class(hamming_weight, input_count)
    
    # Create node mapping for consistent indexing
    node_to_idx = {node: idx for idx, node in enumerate(valid_nodes)}
    
    # Create enhanced node features
    node_features = create_enhanced_node_features(circuit_graph, valid_nodes, influence_df, node_mapping)
    
    # Create edge index (undirected for GraphSAGE)
    edges = []
    for edge in slice_subgraph.edges():
        if edge[0] in node_to_idx and edge[1] in node_to_idx:
            src_idx = node_to_idx[edge[0]]
            dst_idx = node_to_idx[edge[1]]
            edges.append([src_idx, dst_idx])
            edges.append([dst_idx, src_idx])  # Make undirected
    
    if edges:
        edge_index = np.array(edges).T
    else:
        edge_index = np.array([[], []], dtype=np.int64)
    
    # Create PyTorch Geometric Data object
    data = Data(
        x=torch.tensor(node_features, dtype=torch.float),
        edge_index=torch.tensor(edge_index, dtype=torch.long),
        y=torch.tensor(class_label, dtype=torch.long),  # Classification target
        num_nodes=len(valid_nodes),
        hamming_weight=hamming_weight,  # Keep original for analysis
        input_count=input_count,  # For ratio calculation
        slice_label=slice_label,
        circuit_name=""  # Will be set in process_circuit
    )
    
    return data

def process_circuit(circuit_dir):
    """
    Process all slices for a single circuit with classification targets
    """
    data_list = []
    circuit_name = os.path.basename(circuit_dir)
    
    # Find the bench file
    bench_files = [f for f in os.listdir(circuit_dir) 
                   if f.endswith('.bench') or f.endswith('.txt')]
    
    if not bench_files:
        print(f"No bench file found in {circuit_dir}")
        return data_list
    
    bench_file = bench_files[0]
    bench_path = os.path.join(circuit_dir, bench_file)
    print(f"Using bench file: {bench_file}")
    
    # Parse the complete circuit structure
    try:
        circuit_graph = parse_bench_file(bench_path)
        print(f"Parsed circuit with {circuit_graph.number_of_nodes()} nodes and {circuit_graph.number_of_edges()} edges")
    except Exception as e:
        print(f"Error parsing bench file {bench_path}: {e}")
        return data_list
    
    # Load hamming distance data
    hamming_path = os.path.join(circuit_dir, 'hamming_distance.csv')
    if not os.path.exists(hamming_path):
        print(f"Hamming distance file not found: {hamming_path}")
        return data_list
    
    try:
        hamming_df = pd.read_csv(hamming_path)
        print(f"Loaded hamming data with columns: {hamming_df.columns.tolist()}")
    except Exception as e:
        print(f"Error reading hamming distance file: {e}")
        return data_list
    
    # Find required columns
    slice_label_columns = ['Slice label', 'slice_label', 'Slice_label', 'slice', 'Slice', 'label', 'Label']
    hamming_weight_columns = ['Hamming weight', 'hamming_weight', 'Hamming_weight', 'weight', 'Weight']
    
    slice_col = None
    hamming_col = None
    
    for col in slice_label_columns:
        if col in hamming_df.columns:
            slice_col = col
            break
    
    for col in hamming_weight_columns:
        if col in hamming_df.columns:
            hamming_col = col
            break
    
    if slice_col is None or hamming_col is None:
        print(f"Required columns not found. Available columns: {hamming_df.columns.tolist()}")
        return data_list
    
    print(f"Using slice column: '{slice_col}' and hamming column: '{hamming_col}'")
    
    # Check influence directory
    influence_dir = os.path.join(circuit_dir, 'influence')
    if not os.path.exists(influence_dir):
        print(f"Influence directory not found: {influence_dir}")
        return data_list
    
    # Get all influence files
    influence_files = [f for f in os.listdir(influence_dir) if f.endswith('.csv')]
    print(f"Found {len(influence_files)} influence files: {influence_files}")
    
    # Process each slice
    for _, row in hamming_df.iterrows():
        slice_label = str(row[slice_col]).strip()
        hamming_weight = float(row[hamming_col])
        
        # Find corresponding influence file
        influence_file = None
        
        if f'{slice_label}.csv' in influence_files:
            influence_file = f'{slice_label}.csv'
        else:
            for inf_file in influence_files:
                inf_label = os.path.splitext(inf_file)[0]
                if inf_label == slice_label or slice_label in inf_file:
                    influence_file = inf_file
                    break
        
        if influence_file is None:
            print(f"No matching influence file found for slice '{slice_label}'")
            continue
        
        influence_file_path = os.path.join(influence_dir, influence_file)
        
        # Create data object for this slice
        try:
            data = prepare_slice_data_classification(circuit_graph, influence_file_path, hamming_weight, slice_label)
            if data is not None:
                data.circuit_name = circuit_name
                data_list.append(data)
                print(f"✓ Processed slice '{slice_label}' with {data.num_nodes} nodes, class: {data.y.item()}")
            else:
                print(f"✗ Failed to process slice '{slice_label}'")
        except Exception as e:
            print(f"✗ Error processing slice '{slice_label}': {e}")
    
    return data_list

def load_all_circuit_data(circuits_root_dir):
    """
    Load data from all circuits in the root directory
    """
    all_data = []
    
    circuit_dirs = [d for d in os.listdir(circuits_root_dir) 
                   if os.path.isdir(os.path.join(circuits_root_dir, d))]
    
    print(f"Found {len(circuit_dirs)} circuit directories: {circuit_dirs}")
    
    for circuit_name in circuit_dirs:
        circuit_path = os.path.join(circuits_root_dir, circuit_name)
        print(f"\n{'='*50}")
        print(f"Processing circuit: {circuit_name}")
        print(f"{'='*50}")
        
        circuit_data = process_circuit(circuit_path)
        all_data.extend(circuit_data)
        print(f"Added {len(circuit_data)} slices from {circuit_name}")
    
    print(f"\n{'='*50}")
    print(f"SUMMARY: Total data objects created: {len(all_data)}")
    
    return all_data

def analyze_classification_distribution(all_data):
    """
    Analyze the distribution of classification targets
    """
    class_counts = {}
    ratios = []
    
    for data in all_data:
        class_label = data.y.item()
        class_counts[class_label] = class_counts.get(class_label, 0) + 1
        
        # Calculate ratio for analysis
        try:
            log_hamming = math.log10(data.hamming_weight) if data.hamming_weight > 0 else -float('inf')
            log_total_space = data.input_count * math.log10(2)
            log_ratio = log_hamming - log_total_space
            ratio = 10 ** log_ratio if log_ratio > -float('inf') else 0.0
            ratios.append(ratio)
        except:
            ratios.append(0.0)
    
    print("\nClassification Distribution:")
    for class_id, count in sorted(class_counts.items()):
        percentage = count / len(all_data) * 100
        print(f"Class {class_id}: {count} samples ({percentage:.1f}%)")
    
    print(f"\nRatio statistics:")
    print(f"Min ratio: {min(ratios):.6f}")
    print(f"Max ratio: {max(ratios):.6f}")
    print(f"Mean ratio: {np.mean(ratios):.6f}")
    
    return class_counts

# %%
circuits_dir = "c:\\Users\\sidharth\\Documents\\Projects\\boolean-ml\\data\\circuits" 
all_data = load_all_circuit_data(circuits_dir)
# Out:
# Found 10 circuit directories: ['apex2', 'apex4', 'des', 'ex1010', 'ex5', 'i7', 'i8', 'i9', 'k2', 'seq']
#
# ==================================================
# Processing circuit: apex2
# ==================================================
# Using bench file: apex2.bench.txt
# Parsed circuit with 649 nodes and 955 edges
# Loaded hamming data with columns: ['Slice label', 'Hamming weight', ' Input count', ' HW to Domain size ratio', ' Runtime']
# Using slice column: 'Slice label' and hamming column: 'Hamming weight'
# Found 3 influence files: ['G39.csv', 'G40.csv', 'G41.csv']
#
# Processing slice G39
# Analyzing influence DataFrame with columns: ['Input', 'Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G1', 'G2', 'G3', 'G4']...
# Mapped 36 nodes out of 36 influence nodes
# Extended to 273 nodes (from 36 primary inputs)
# Subgraph has 325 edges
# ✓ Processed slice 'G39' with 273 nodes, class: 1
#
# Processing slice G40
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G1', 'G2', 'G3', 'G4']...
# Mapped 36 nodes out of 36 influence nodes
# Extended to 268 nodes (from 36 primary inputs)
# Subgraph has 314 edges
# ✓ Processed slice 'G40' with 268 nodes, class: 1
#
# Processing slice G41
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 35 nodes out of 35 influence nodes
# Extended to 272 nodes (from 35 primary inputs)
# Subgraph has 322 edges
# ✓ Processed slice 'G41' with 272 nodes, class: 2
# Added 3 slices from apex2
#
# ==================================================
# Processing circuit: apex4
# ==================================================
# Using bench file: apex4.bench
# Parsed circuit with 5370 nodes and 8246 edges
# Loaded hamming data with columns: ['Slice label', 'Hamming weight', ' Input count', ' HW to Domain size ratio', ' Runtime']
# Using slice column: 'Slice label' and hamming column: 'Hamming weight'
# Found 19 influence files: ['G10.csv', 'G11.csv', 'G12.csv', 'G13.csv', 'G14.csv', 'G15.csv', 'G16.csv', 'G17.csv', 'G18.csv', 'G19.csv', 'G20.csv', 'G21.csv', 'G22.csv', 'G23.csv', 'G24.csv', 'G25.csv', 'G26.csv', 'G27.csv', 'G28.csv']
#
# Processing slice G10
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0']...
# Mapped 1 nodes out of 1 influence nodes
# Extended to 268 nodes (from 1 primary inputs)
# Subgraph has 267 edges
# ✓ Processed slice 'G10' with 268 nodes, class: 2
#
# Processing slice G11
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 8 nodes out of 9 influence nodes
# Extended to 1337 nodes (from 8 primary inputs)
# Subgraph has 1631 edges
# ✓ Processed slice 'G11' with 1337 nodes, class: 2
#
# Processing slice G12
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 8 nodes out of 9 influence nodes
# Extended to 1337 nodes (from 8 primary inputs)
# Subgraph has 1631 edges
# ✓ Processed slice 'G12' with 1337 nodes, class: 2
#
# Processing slice G13
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 8 nodes out of 9 influence nodes
# Extended to 1337 nodes (from 8 primary inputs)
# Subgraph has 1631 edges
# ✓ Processed slice 'G13' with 1337 nodes, class: 2
#
# Processing slice G14
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 8 nodes out of 9 influence nodes
# Extended to 1337 nodes (from 8 primary inputs)
# Subgraph has 1631 edges
# ✓ Processed slice 'G14' with 1337 nodes, class: 2
#
# Processing slice G15
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 8 nodes out of 9 influence nodes
# Extended to 1337 nodes (from 8 primary inputs)
# Subgraph has 1631 edges
# ✓ Processed slice 'G15' with 1337 nodes, class: 2
#
# Processing slice G16
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 8 nodes out of 9 influence nodes
# Extended to 1337 nodes (from 8 primary inputs)
# Subgraph has 1631 edges
# ✓ Processed slice 'G16' with 1337 nodes, class: 2
#
# Processing slice G17
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 8 nodes out of 9 influence nodes
# Extended to 1337 nodes (from 8 primary inputs)
# Subgraph has 1631 edges
# ✓ Processed slice 'G17' with 1337 nodes, class: 2
#
# Processing slice G18
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 8 nodes out of 9 influence nodes
# Extended to 1337 nodes (from 8 primary inputs)
# Subgraph has 1631 edges
# ✓ Processed slice 'G18' with 1337 nodes, class: 2
#
# Processing slice G19
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 8 nodes out of 9 influence nodes
# Extended to 1337 nodes (from 8 primary inputs)
# Subgraph has 1631 edges
# ✓ Processed slice 'G19' with 1337 nodes, class: 2
#
# Processing slice G20
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 8 nodes out of 9 influence nodes
# Extended to 1337 nodes (from 8 primary inputs)
# Subgraph has 1631 edges
# ✓ Processed slice 'G20' with 1337 nodes, class: 2
#
# Processing slice G21
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 8 nodes out of 9 influence nodes
# Extended to 1337 nodes (from 8 primary inputs)
# Subgraph has 1631 edges
# ✓ Processed slice 'G21' with 1337 nodes, class: 2
#
# Processing slice G22
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 8 nodes out of 9 influence nodes
# Extended to 1337 nodes (from 8 primary inputs)
# Subgraph has 1631 edges
# ✓ Processed slice 'G22' with 1337 nodes, class: 2
#
# Processing slice G23
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 8 nodes out of 9 influence nodes
# Extended to 1337 nodes (from 8 primary inputs)
# Subgraph has 1631 edges
# ✓ Processed slice 'G23' with 1337 nodes, class: 2
#
# Processing slice G24
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 8 nodes out of 9 influence nodes
# Extended to 1337 nodes (from 8 primary inputs)
# Subgraph has 1631 edges
# ✓ Processed slice 'G24' with 1337 nodes, class: 2
#
# Processing slice G25
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 8 nodes out of 9 influence nodes
# Extended to 1337 nodes (from 8 primary inputs)
# Subgraph has 1631 edges
# ✓ Processed slice 'G25' with 1337 nodes, class: 2
#
# Processing slice G26
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 8 nodes out of 9 influence nodes
# Extended to 1337 nodes (from 8 primary inputs)
# Subgraph has 1631 edges
# ✓ Processed slice 'G26' with 1337 nodes, class: 2
#
# Processing slice G27
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 8 nodes out of 9 influence nodes
# Extended to 1337 nodes (from 8 primary inputs)
# Subgraph has 1631 edges
# ✓ Processed slice 'G27' with 1337 nodes, class: 2
#
# Processing slice G28
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 8 nodes out of 9 influence nodes
# Extended to 1337 nodes (from 8 primary inputs)
# Subgraph has 1631 edges
# ✓ Processed slice 'G28' with 1337 nodes, class: 2
# Added 19 slices from apex4
#
# ==================================================
# Processing circuit: des
# ==================================================
# Using bench file: des.bench
# Parsed circuit with 6729 nodes and 10312 edges
# Loaded hamming data with columns: ['Slice label', 'Hamming weight', ' Input count', ' HW to Domain size ratio', ' Runtime']
# Using slice column: 'Slice label' and hamming column: 'Hamming weight'
# Found 245 influence files: ['G256.csv', 'G257.csv', 'G258.csv', 'G259.csv', 'G260.csv', 'G261.csv', 'G262.csv', 'G263.csv', 'G264.csv', 'G265.csv', 'G266.csv', 'G267.csv', 'G268.csv', 'G269.csv', 'G270.csv', 'G271.csv', 'G272.csv', 'G273.csv', 'G274.csv', 'G275.csv', 'G276.csv', 'G277.csv', 'G278.csv', 'G279.csv', 'G280.csv', 'G281.csv', 'G282.csv', 'G283.csv', 'G284.csv', 'G285.csv', 'G286.csv', 'G287.csv', 'G288.csv', 'G289.csv', 'G290.csv', 'G291.csv', 'G292.csv', 'G293.csv', 'G294.csv', 'G295.csv', 'G296.csv', 'G297.csv', 'G298.csv', 'G299.csv', 'G300.csv', 'G301.csv', 'G302.csv', 'G303.csv', 'G304.csv', 'G305.csv', 'G306.csv', 'G307.csv', 'G308.csv', 'G309.csv', 'G310.csv', 'G311.csv', 'G312.csv', 'G313.csv', 'G314.csv', 'G315.csv', 'G316.csv', 'G317.csv', 'G318.csv', 'G319.csv', 'G320.csv', 'G321.csv', 'G322.csv', 'G323.csv', 'G324.csv', 'G325.csv', 'G326.csv', 'G327.csv', 'G328.csv', 'G329.csv', 'G330.csv', 'G331.csv', 'G332.csv', 'G333.csv', 'G334.csv', 'G335.csv', 'G336.csv', 'G337.csv', 'G338.csv', 'G339.csv', 'G340.csv', 'G341.csv', 'G342.csv', 'G343.csv', 'G344.csv', 'G345.csv', 'G346.csv', 'G347.csv', 'G348.csv', 'G349.csv', 'G350.csv', 'G351.csv', 'G352.csv', 'G353.csv', 'G354.csv', 'G355.csv', 'G356.csv', 'G357.csv', 'G358.csv', 'G359.csv', 'G360.csv', 'G361.csv', 'G362.csv', 'G363.csv', 'G364.csv', 'G365.csv', 'G366.csv', 'G367.csv', 'G368.csv', 'G369.csv', 'G370.csv', 'G371.csv', 'G372.csv', 'G373.csv', 'G374.csv', 'G375.csv', 'G376.csv', 'G377.csv', 'G378.csv', 'G379.csv', 'G380.csv', 'G381.csv', 'G382.csv', 'G383.csv', 'G384.csv', 'G385.csv', 'G386.csv', 'G387.csv', 'G388.csv', 'G389.csv', 'G390.csv', 'G391.csv', 'G392.csv', 'G393.csv', 'G394.csv', 'G395.csv', 'G396.csv', 'G397.csv', 'G398.csv', 'G399.csv', 'G400.csv', 'G401.csv', 'G402.csv', 'G403.csv', 'G404.csv', 'G405.csv', 'G406.csv', 'G407.csv', 'G408.csv', 'G409.csv', 'G410.csv', 'G411.csv', 'G412.csv', 'G413.csv', 'G414.csv', 'G415.csv', 'G416.csv', 'G417.csv', 'G418.csv', 'G419.csv', 'G420.csv', 'G421.csv', 'G422.csv', 'G423.csv', 'G424.csv', 'G425.csv', 'G426.csv', 'G427.csv', 'G428.csv', 'G429.csv', 'G430.csv', 'G431.csv', 'G432.csv', 'G433.csv', 'G434.csv', 'G435.csv', 'G436.csv', 'G437.csv', 'G438.csv', 'G439.csv', 'G440.csv', 'G441.csv', 'G442.csv', 'G443.csv', 'G444.csv', 'G445.csv', 'G446.csv', 'G447.csv', 'G448.csv', 'G449.csv', 'G450.csv', 'G451.csv', 'G452.csv', 'G453.csv', 'G454.csv', 'G455.csv', 'G456.csv', 'G457.csv', 'G458.csv', 'G459.csv', 'G460.csv', 'G461.csv', 'G462.csv', 'G463.csv', 'G464.csv', 'G465.csv', 'G466.csv', 'G467.csv', 'G468.csv', 'G469.csv', 'G470.csv', 'G471.csv', 'G472.csv', 'G473.csv', 'G474.csv', 'G475.csv', 'G476.csv', 'G477.csv', 'G478.csv', 'G479.csv', 'G480.csv', 'G481.csv', 'G482.csv', 'G483.csv', 'G484.csv', 'G485.csv', 'G486.csv', 'G487.csv', 'G488.csv', 'G489.csv', 'G490.csv', 'G491.csv', 'G492.csv', 'G493.csv', 'G494.csv', 'G495.csv', 'G496.csv', 'G497.csv', 'G498.csv', 'G499.csv', 'G500.csv']
#
# Processing slice G256
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G11', 'G19', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G256' with 253 nodes, class: 2
#
# Processing slice G257
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G12', 'G20', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G257' with 253 nodes, class: 2
#
# Processing slice G258
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G13', 'G21', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G258' with 253 nodes, class: 2
#
# Processing slice G259
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G14', 'G22', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G259' with 253 nodes, class: 2
#
# Processing slice G260
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G15', 'G23', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G260' with 253 nodes, class: 2
#
# Processing slice G261
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G16', 'G24', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G261' with 253 nodes, class: 2
#
# Processing slice G262
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G17', 'G25', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G262' with 253 nodes, class: 2
#
# Processing slice G263
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G18', 'G26', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G263' with 253 nodes, class: 2
#
# Processing slice G264
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G19', 'G27', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G264' with 253 nodes, class: 2
#
# Processing slice G265
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G20', 'G28', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G265' with 253 nodes, class: 2
#
# Processing slice G266
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G21', 'G29', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G266' with 253 nodes, class: 2
#
# Processing slice G267
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G22', 'G30', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G267' with 253 nodes, class: 2
#
# Processing slice G268
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G23', 'G31', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G268' with 253 nodes, class: 2
#
# Processing slice G269
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G24', 'G32', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G269' with 253 nodes, class: 2
#
# Processing slice G270
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G25', 'G33', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G270' with 253 nodes, class: 2
#
# Processing slice G271
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G26', 'G34', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G271' with 253 nodes, class: 2
#
# Processing slice G272
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G27', 'G35', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G272' with 253 nodes, class: 2
#
# Processing slice G273
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G28', 'G36', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G273' with 253 nodes, class: 2
#
# Processing slice G274
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G29', 'G37', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G274' with 253 nodes, class: 2
#
# Processing slice G275
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G30', 'G38', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G275' with 253 nodes, class: 2
#
# Processing slice G276
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G31', 'G39', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G276' with 253 nodes, class: 2
#
# Processing slice G277
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G32', 'G40', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G277' with 253 nodes, class: 2
#
# Processing slice G278
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G33', 'G41', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G278' with 253 nodes, class: 2
#
# Processing slice G279
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G34', 'G42', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G279' with 253 nodes, class: 2
#
# Processing slice G280
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G35', 'G43', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G280' with 253 nodes, class: 2
#
# Processing slice G281
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G36', 'G44', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G281' with 253 nodes, class: 2
#
# Processing slice G282
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G37', 'G45', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G282' with 253 nodes, class: 2
#
# Processing slice G283
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G38', 'G46', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G283' with 253 nodes, class: 2
#
# Processing slice G284
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G39', 'G47', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G284' with 253 nodes, class: 2
#
# Processing slice G285
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G40', 'G48', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G285' with 253 nodes, class: 2
#
# Processing slice G286
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G41', 'G49', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G286' with 253 nodes, class: 2
#
# Processing slice G287
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G42', 'G50', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G287' with 253 nodes, class: 2
#
# Processing slice G288
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G43', 'G51', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G288' with 253 nodes, class: 2
#
# Processing slice G289
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G44', 'G52', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G289' with 253 nodes, class: 2
#
# Processing slice G290
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G45', 'G53', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G290' with 253 nodes, class: 2
#
# Processing slice G291
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G46', 'G54', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G291' with 253 nodes, class: 2
#
# Processing slice G292
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G47', 'G55', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G292' with 253 nodes, class: 2
#
# Processing slice G293
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G48', 'G56', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G293' with 253 nodes, class: 2
#
# Processing slice G294
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G49', 'G57', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G294' with 253 nodes, class: 2
#
# Processing slice G295
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G50', 'G58', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G295' with 253 nodes, class: 2
#
# Processing slice G296
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G51', 'G59', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G296' with 253 nodes, class: 2
#
# Processing slice G297
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G52', 'G60', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G297' with 253 nodes, class: 2
#
# Processing slice G298
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G53', 'G61', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G298' with 253 nodes, class: 2
#
# Processing slice G299
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G54', 'G62', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G299' with 253 nodes, class: 2
#
# Processing slice G300
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G55', 'G63', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G300' with 253 nodes, class: 2
#
# Processing slice G301
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G56', 'G64', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G301' with 253 nodes, class: 2
#
# Processing slice G302
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G57', 'G65', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G302' with 253 nodes, class: 2
#
# Processing slice G303
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G58', 'G66', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G303' with 253 nodes, class: 2
#
# Processing slice G304
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G59', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G304' with 253 nodes, class: 2
#
# Processing slice G305
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G60', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G305' with 253 nodes, class: 2
#
# Processing slice G306
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G2', 'G61', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G306' with 253 nodes, class: 2
#
# Processing slice G307
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G3', 'G62', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G307' with 253 nodes, class: 2
#
# Processing slice G308
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G4', 'G63', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G308' with 253 nodes, class: 2
#
# Processing slice G309
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G5', 'G64', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G309' with 253 nodes, class: 2
#
# Processing slice G310
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G6', 'G65', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G310' with 253 nodes, class: 2
#
# Processing slice G311
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G7', 'G66', 'G195', 'G196', 'G197']...
# Mapped 4 nodes out of 6 influence nodes
# Extended to 253 nodes (from 4 primary inputs)
# Subgraph has 261 edges
# ✓ Processed slice 'G311' with 253 nodes, class: 2
#
# Processing slice G312
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G67', 'G142', 'G143', 'G144', 'G145']...
# Mapped 17 nodes out of 18 influence nodes
# Extended to 378 nodes (from 17 primary inputs)
# Subgraph has 391 edges
# ✓ Processed slice 'G312' with 378 nodes, class: 2
#
# Processing slice G313
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G68', 'G138', 'G195', 'G196', 'G197']...
# Mapped 5 nodes out of 6 influence nodes
# Extended to 265 nodes (from 5 primary inputs)
# Subgraph has 273 edges
# ✓ Processed slice 'G313' with 265 nodes, class: 2
#
# Processing slice G314
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G69', 'G131', 'G158', 'G159', 'G160']...
# Mapped 17 nodes out of 18 influence nodes
# Extended to 378 nodes (from 17 primary inputs)
# Subgraph has 391 edges
# ✓ Processed slice 'G314' with 378 nodes, class: 2
#
# Processing slice G315
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G70', 'G146', 'G195', 'G196', 'G197']...
# Mapped 5 nodes out of 6 influence nodes
# Extended to 265 nodes (from 5 primary inputs)
# Subgraph has 273 edges
# ✓ Processed slice 'G315' with 265 nodes, class: 2
#
# Processing slice G316
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G71', 'G131', 'G158', 'G159', 'G160']...
# Mapped 17 nodes out of 18 influence nodes
# Extended to 378 nodes (from 17 primary inputs)
# Subgraph has 391 edges
# ✓ Processed slice 'G316' with 378 nodes, class: 2
#
# Processing slice G317
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G72', 'G154', 'G195', 'G196', 'G197']...
# Mapped 5 nodes out of 6 influence nodes
# Extended to 265 nodes (from 5 primary inputs)
# Subgraph has 273 edges
# ✓ Processed slice 'G317' with 265 nodes, class: 2
#
# Processing slice G318
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G73', 'G146', 'G147', 'G148', 'G149']...
# Mapped 17 nodes out of 18 influence nodes
# Extended to 378 nodes (from 17 primary inputs)
# Subgraph has 391 edges
# ✓ Processed slice 'G318' with 378 nodes, class: 2
#
# Processing slice G319
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G74', 'G162', 'G195', 'G196', 'G197']...
# Mapped 5 nodes out of 6 influence nodes
# Extended to 265 nodes (from 5 primary inputs)
# Subgraph has 273 edges
# ✓ Processed slice 'G319' with 265 nodes, class: 2
#
# Processing slice G320
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G67', 'G75', 'G146', 'G147', 'G148']...
# Mapped 17 nodes out of 19 influence nodes
# Extended to 378 nodes (from 17 primary inputs)
# Subgraph has 391 edges
# ✓ Processed slice 'G320' with 378 nodes, class: 2
#
# Processing slice G321
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G68', 'G76', 'G137', 'G195', 'G196']...
# Mapped 5 nodes out of 7 influence nodes
# Extended to 262 nodes (from 5 primary inputs)
# Subgraph has 270 edges
# ✓ Processed slice 'G321' with 262 nodes, class: 2
#
# Processing slice G322
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G69', 'G77', 'G154', 'G155', 'G156']...
# Mapped 17 nodes out of 19 influence nodes
# Extended to 378 nodes (from 17 primary inputs)
# Subgraph has 391 edges
# ✓ Processed slice 'G322' with 378 nodes, class: 2
#
# Processing slice G323
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G70', 'G78', 'G145', 'G195', 'G196']...
# Mapped 5 nodes out of 7 influence nodes
# Extended to 262 nodes (from 5 primary inputs)
# Subgraph has 270 edges
# ✓ Processed slice 'G323' with 262 nodes, class: 2
#
# Processing slice G324
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G71', 'G79', 'G146', 'G147', 'G148']...
# Mapped 17 nodes out of 19 influence nodes
# Extended to 378 nodes (from 17 primary inputs)
# Subgraph has 391 edges
# ✓ Processed slice 'G324' with 378 nodes, class: 2
#
# Processing slice G325
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G72', 'G80', 'G153', 'G195', 'G196']...
# Mapped 5 nodes out of 7 influence nodes
# Extended to 262 nodes (from 5 primary inputs)
# Subgraph has 270 edges
# ✓ Processed slice 'G325' with 262 nodes, class: 2
#
# Processing slice G326
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G73', 'G81', 'G154', 'G155', 'G156']...
# Mapped 17 nodes out of 19 influence nodes
# Extended to 378 nodes (from 17 primary inputs)
# Subgraph has 391 edges
# ✓ Processed slice 'G326' with 378 nodes, class: 2
#
# Processing slice G327
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G74', 'G82', 'G161', 'G195', 'G196']...
# Mapped 5 nodes out of 7 influence nodes
# Extended to 262 nodes (from 5 primary inputs)
# Subgraph has 270 edges
# ✓ Processed slice 'G327' with 262 nodes, class: 2
#
# Processing slice G328
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G75', 'G83', 'G131', 'G132', 'G133']...
# Mapped 17 nodes out of 19 influence nodes
# Extended to 378 nodes (from 17 primary inputs)
# Subgraph has 391 edges
# ✓ Processed slice 'G328' with 378 nodes, class: 2
#
# Processing slice G329
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G76', 'G84', 'G136', 'G195', 'G196']...
# Mapped 5 nodes out of 7 influence nodes
# Extended to 262 nodes (from 5 primary inputs)
# Subgraph has 270 edges
# ✓ Processed slice 'G329' with 262 nodes, class: 2
#
# Processing slice G330
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G77', 'G85', 'G138', 'G139', 'G140']...
# Mapped 17 nodes out of 19 influence nodes
# Extended to 378 nodes (from 17 primary inputs)
# Subgraph has 391 edges
# ✓ Processed slice 'G330' with 378 nodes, class: 2
#
# Processing slice G331
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G78', 'G86', 'G144', 'G195', 'G196']...
# Mapped 5 nodes out of 7 influence nodes
# Extended to 262 nodes (from 5 primary inputs)
# Subgraph has 270 edges
# ✓ Processed slice 'G331' with 262 nodes, class: 2
#
# Processing slice G332
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G79', 'G87', 'G138', 'G139', 'G140']...
# Mapped 17 nodes out of 19 influence nodes
# Extended to 378 nodes (from 17 primary inputs)
# Subgraph has 391 edges
# ✓ Processed slice 'G332' with 378 nodes, class: 2
#
# Processing slice G333
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G80', 'G88', 'G152', 'G195', 'G196']...
# Mapped 5 nodes out of 7 influence nodes
# Extended to 262 nodes (from 5 primary inputs)
# Subgraph has 270 edges
# ✓ Processed slice 'G333' with 262 nodes, class: 2
#
# Processing slice G334
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G81', 'G89', 'G142', 'G143', 'G144']...
# Mapped 17 nodes out of 19 influence nodes
# Extended to 378 nodes (from 17 primary inputs)
# Subgraph has 391 edges
# ✓ Processed slice 'G334' with 378 nodes, class: 2
#
# Processing slice G335
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G82', 'G90', 'G160', 'G195', 'G196']...
# Mapped 5 nodes out of 7 influence nodes
# Extended to 262 nodes (from 5 primary inputs)
# Subgraph has 270 edges
# ✓ Processed slice 'G335' with 262 nodes, class: 2
#
# Processing slice G336
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G83', 'G91', 'G154', 'G155', 'G156']...
# Mapped 17 nodes out of 19 influence nodes
# Extended to 378 nodes (from 17 primary inputs)
# Subgraph has 391 edges
# ✓ Processed slice 'G336' with 378 nodes, class: 2
#
# Processing slice G337
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G84', 'G92', 'G135', 'G195', 'G196']...
# Mapped 5 nodes out of 7 influence nodes
# Extended to 265 nodes (from 5 primary inputs)
# Subgraph has 273 edges
# ✓ Processed slice 'G337' with 265 nodes, class: 2
#
# Processing slice G338
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G85', 'G93', 'G146', 'G147', 'G148']...
# Mapped 17 nodes out of 19 influence nodes
# Extended to 378 nodes (from 17 primary inputs)
# Subgraph has 391 edges
# ✓ Processed slice 'G338' with 378 nodes, class: 2
#
# Processing slice G339
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G86', 'G94', 'G143', 'G195', 'G196']...
# Mapped 5 nodes out of 7 influence nodes
# Extended to 265 nodes (from 5 primary inputs)
# Subgraph has 273 edges
# ✓ Processed slice 'G339' with 265 nodes, class: 2
#
# Processing slice G340
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G87', 'G95', 'G134', 'G135', 'G136']...
# Mapped 17 nodes out of 19 influence nodes
# Extended to 378 nodes (from 17 primary inputs)
# Subgraph has 391 edges
# ✓ Processed slice 'G340' with 378 nodes, class: 2
#
# Processing slice G341
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G88', 'G96', 'G151', 'G195', 'G196']...
# Mapped 5 nodes out of 7 influence nodes
# Extended to 265 nodes (from 5 primary inputs)
# Subgraph has 273 edges
# ✓ Processed slice 'G341' with 265 nodes, class: 2
#
# Processing slice G342
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G89', 'G97', 'G138', 'G139', 'G140']...
# Mapped 17 nodes out of 19 influence nodes
# Extended to 378 nodes (from 17 primary inputs)
# Subgraph has 391 edges
# ✓ Processed slice 'G342' with 378 nodes, class: 2
#
# Processing slice G343
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G90', 'G98', 'G159', 'G195', 'G196']...
# Mapped 5 nodes out of 7 influence nodes
# Extended to 265 nodes (from 5 primary inputs)
# Subgraph has 273 edges
# ✓ Processed slice 'G343' with 265 nodes, class: 2
#
# Processing slice G344
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G91', 'G99', 'G138', 'G139', 'G140']...
# Mapped 17 nodes out of 19 influence nodes
# Extended to 378 nodes (from 17 primary inputs)
# Subgraph has 391 edges
# ✓ Processed slice 'G344' with 378 nodes, class: 2
#
# Processing slice G345
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G92', 'G100', 'G134', 'G195', 'G196']...
# Mapped 6 nodes out of 7 influence nodes
# Extended to 268 nodes (from 6 primary inputs)
# Subgraph has 277 edges
# ✓ Processed slice 'G345' with 268 nodes, class: 2
#
# Processing slice G346
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G93', 'G101', 'G131', 'G132', 'G133']...
# Mapped 18 nodes out of 19 influence nodes
# Extended to 381 nodes (from 18 primary inputs)
# Subgraph has 395 edges
# ✓ Processed slice 'G346' with 381 nodes, class: 2
#
# Processing slice G347
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G94', 'G102', 'G142', 'G195', 'G196']...
# Mapped 6 nodes out of 7 influence nodes
# Extended to 268 nodes (from 6 primary inputs)
# Subgraph has 277 edges
# ✓ Processed slice 'G347' with 268 nodes, class: 2
#
# Processing slice G348
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G95', 'G103', 'G154', 'G155', 'G156']...
# Mapped 18 nodes out of 19 influence nodes
# Extended to 381 nodes (from 18 primary inputs)
# Subgraph has 395 edges
# ✓ Processed slice 'G348' with 381 nodes, class: 2
#
# Processing slice G349
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G96', 'G104', 'G150', 'G195', 'G196']...
# Mapped 6 nodes out of 7 influence nodes
# Extended to 268 nodes (from 6 primary inputs)
# Subgraph has 277 edges
# ✓ Processed slice 'G349' with 268 nodes, class: 2
#
# Processing slice G350
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G97', 'G105', 'G131', 'G132', 'G133']...
# Mapped 18 nodes out of 19 influence nodes
# Extended to 381 nodes (from 18 primary inputs)
# Subgraph has 395 edges
# ✓ Processed slice 'G350' with 381 nodes, class: 2
#
# Processing slice G351
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G98', 'G106', 'G158', 'G195', 'G196']...
# Mapped 6 nodes out of 7 influence nodes
# Extended to 268 nodes (from 6 primary inputs)
# Subgraph has 277 edges
# ✓ Processed slice 'G351' with 268 nodes, class: 2
#
# Processing slice G352
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G99', 'G107', 'G150', 'G151', 'G152']...
# Mapped 18 nodes out of 19 influence nodes
# Extended to 381 nodes (from 18 primary inputs)
# Subgraph has 395 edges
# ✓ Processed slice 'G352' with 381 nodes, class: 2
#
# Processing slice G353
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G100', 'G108', 'G133', 'G195', 'G196']...
# Mapped 7 nodes out of 7 influence nodes
# Extended to 268 nodes (from 7 primary inputs)
# Subgraph has 278 edges
# ✓ Processed slice 'G353' with 268 nodes, class: 2
#
# Processing slice G354
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G101', 'G109', 'G134', 'G135', 'G136']...
# Mapped 19 nodes out of 19 influence nodes
# Extended to 384 nodes (from 19 primary inputs)
# Subgraph has 399 edges
# ✓ Processed slice 'G354' with 384 nodes, class: 2
#
# Processing slice G355
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G102', 'G110', 'G141', 'G195', 'G196']...
# Mapped 7 nodes out of 7 influence nodes
# Extended to 268 nodes (from 7 primary inputs)
# Subgraph has 278 edges
# ✓ Processed slice 'G355' with 268 nodes, class: 2
#
# Processing slice G356
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G103', 'G111', 'G142', 'G143', 'G144']...
# Mapped 19 nodes out of 19 influence nodes
# Extended to 384 nodes (from 19 primary inputs)
# Subgraph has 399 edges
# ✓ Processed slice 'G356' with 384 nodes, class: 2
#
# Processing slice G357
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G104', 'G112', 'G149', 'G195', 'G196']...
# Mapped 7 nodes out of 7 influence nodes
# Extended to 268 nodes (from 7 primary inputs)
# Subgraph has 278 edges
# ✓ Processed slice 'G357' with 268 nodes, class: 2
#
# Processing slice G358
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G105', 'G113', 'G150', 'G151', 'G152']...
# Mapped 19 nodes out of 19 influence nodes
# Extended to 384 nodes (from 19 primary inputs)
# Subgraph has 399 edges
# ✓ Processed slice 'G358' with 384 nodes, class: 2
#
# Processing slice G359
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G106', 'G114', 'G157', 'G195', 'G196']...
# Mapped 7 nodes out of 7 influence nodes
# Extended to 268 nodes (from 7 primary inputs)
# Subgraph has 278 edges
# ✓ Processed slice 'G359' with 268 nodes, class: 2
#
# Processing slice G360
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G107', 'G115', 'G131', 'G158', 'G159']...
# Mapped 19 nodes out of 19 influence nodes
# Extended to 384 nodes (from 19 primary inputs)
# Subgraph has 399 edges
# ✓ Processed slice 'G360' with 384 nodes, class: 2
#
# Processing slice G361
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G108', 'G116', 'G132', 'G195', 'G196']...
# Mapped 7 nodes out of 7 influence nodes
# Extended to 268 nodes (from 7 primary inputs)
# Subgraph has 278 edges
# ✓ Processed slice 'G361' with 268 nodes, class: 2
#
# Processing slice G362
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G109', 'G117', 'G131', 'G158', 'G159']...
# Mapped 19 nodes out of 19 influence nodes
# Extended to 384 nodes (from 19 primary inputs)
# Subgraph has 399 edges
# ✓ Processed slice 'G362' with 384 nodes, class: 2
#
# Processing slice G363
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G110', 'G118', 'G140', 'G195', 'G196']...
# Mapped 7 nodes out of 7 influence nodes
# ...
# Found nodes in column 'Input': ['G1', 'G3', 'G4', 'G5', 'G6']...
# Mapped 29 nodes out of 30 influence nodes
# Extended to 579 nodes (from 29 primary inputs)
# Subgraph has 896 edges
# ✓ Processed slice 'G80' with 579 nodes, class: 2
#
# Processing slice G81
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 29 nodes out of 29 influence nodes
# Extended to 582 nodes (from 29 primary inputs)
# Subgraph has 917 edges
# ✓ Processed slice 'G81' with 582 nodes, class: 2
#
# Processing slice G82
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G4', 'G5', 'G6', 'G8']...
# Mapped 34 nodes out of 34 influence nodes
# Extended to 600 nodes (from 34 primary inputs)
# Subgraph has 941 edges
# ✓ Processed slice 'G82' with 600 nodes, class: 2
#
# Processing slice G83
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 40 nodes out of 41 influence nodes
# Extended to 633 nodes (from 40 primary inputs)
# Subgraph has 998 edges
# ✓ Processed slice 'G83' with 633 nodes, class: 2
#
# Processing slice G84
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 21 nodes out of 21 influence nodes
# Extended to 515 nodes (from 21 primary inputs)
# Subgraph has 795 edges
# ✓ Processed slice 'G84' with 515 nodes, class: 1
#
# Processing slice G85
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G2', 'G3', 'G4', 'G5', 'G6']...
# Mapped 20 nodes out of 20 influence nodes
# Extended to 526 nodes (from 20 primary inputs)
# Subgraph has 825 edges
# ✓ Processed slice 'G85' with 526 nodes, class: 2
#
# Processing slice G86
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G4', 'G6', 'G11', 'G19', 'G20']...
# Mapped 13 nodes out of 13 influence nodes
# Extended to 443 nodes (from 13 primary inputs)
# Subgraph has 661 edges
# ✓ Processed slice 'G86' with 443 nodes, class: 1
#
# Processing slice G87
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G6', 'G16', 'G19', 'G20']...
# Mapped 11 nodes out of 11 influence nodes
# Extended to 378 nodes (from 11 primary inputs)
# Subgraph has 525 edges
# ✓ Processed slice 'G87' with 378 nodes, class: 0
#
# Processing slice G88
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0']...
# Mapped 1 nodes out of 1 influence nodes
# Extended to 33 nodes (from 1 primary inputs)
# Subgraph has 32 edges
# ✓ Processed slice 'G88' with 33 nodes, class: 2
#
# Processing slice G89
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G19', 'G20', 'G21', 'G22', 'G23']...
# Mapped 8 nodes out of 8 influence nodes
# Extended to 329 nodes (from 8 primary inputs)
# Subgraph has 436 edges
# ✓ Processed slice 'G89' with 329 nodes, class: 1
#
# Processing slice G90
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G19', 'G20', 'G21', 'G22', 'G23']...
# Mapped 7 nodes out of 7 influence nodes
# Extended to 300 nodes (from 7 primary inputs)
# Subgraph has 380 edges
# ✓ Processed slice 'G90' with 300 nodes, class: 0
# Added 45 slices from k2
#
# ==================================================
# Processing circuit: seq
# ==================================================
# Using bench file: seq.bench
# Parsed circuit with 3560 nodes and 5483 edges
# Loaded hamming data with columns: ['Slice label', 'Hamming weight', ' Input count', ' HW to Domain size ratio', ' Runtime']
# Using slice column: 'Slice label' and hamming column: 'Hamming weight'
# Found 35 influence files: ['G41.csv', 'G42.csv', 'G43.csv', 'G44.csv', 'G45.csv', 'G46.csv', 'G47.csv', 'G48.csv', 'G49.csv', 'G50.csv', 'G51.csv', 'G52.csv', 'G53.csv', 'G54.csv', 'G55.csv', 'G56.csv', 'G57.csv', 'G58.csv', 'G59.csv', 'G60.csv', 'G61.csv', 'G62.csv', 'G63.csv', 'G64.csv', 'G65.csv', 'G66.csv', 'G67.csv', 'G68.csv', 'G69.csv', 'G70.csv', 'G71.csv', 'G72.csv', 'G73.csv', 'G74.csv', 'G75.csv']
#
# Processing slice G41
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G1', 'G2', 'G3', 'G4']...
# Mapped 37 nodes out of 37 influence nodes
# Extended to 1151 nodes (from 37 primary inputs)
# Subgraph has 1486 edges
# ✓ Processed slice 'G41' with 1151 nodes, class: 1
#
# Processing slice G42
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 27 nodes out of 27 influence nodes
# Extended to 1019 nodes (from 27 primary inputs)
# Subgraph has 1293 edges
# ✓ Processed slice 'G42' with 1019 nodes, class: 2
#
# Processing slice G43
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G1', 'G2', 'G3', 'G4', 'G5']...
# Mapped 36 nodes out of 36 influence nodes
# Extended to 1103 nodes (from 36 primary inputs)
# Subgraph has 1416 edges
# ✓ Processed slice 'G43' with 1103 nodes, class: 2
#
# Processing slice G44
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G1', 'G2', 'G3', 'G4']...
# Mapped 36 nodes out of 36 influence nodes
# Extended to 1149 nodes (from 36 primary inputs)
# Subgraph has 1485 edges
# ✓ Processed slice 'G44' with 1149 nodes, class: 2
#
# Processing slice G45
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G1', 'G4', 'G5', 'G7']...
# Mapped 36 nodes out of 36 influence nodes
# Extended to 1139 nodes (from 36 primary inputs)
# Subgraph has 1469 edges
# ✓ Processed slice 'G45' with 1139 nodes, class: 1
#
# Processing slice G46
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G1', 'G2', 'G3', 'G4']...
# Mapped 38 nodes out of 38 influence nodes
# Extended to 1154 nodes (from 38 primary inputs)
# Subgraph has 1494 edges
# ✓ Processed slice 'G46' with 1154 nodes, class: 1
#
# Processing slice G47
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G1', 'G2', 'G3', 'G4']...
# Mapped 33 nodes out of 33 influence nodes
# Extended to 1129 nodes (from 33 primary inputs)
# Subgraph has 1452 edges
# ✓ Processed slice 'G47' with 1129 nodes, class: 1
#
# Processing slice G48
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G5', 'G7', 'G9', 'G11', 'G12']...
# Mapped 27 nodes out of 27 influence nodes
# Extended to 1020 nodes (from 27 primary inputs)
# Subgraph has 1295 edges
# ✓ Processed slice 'G48' with 1020 nodes, class: 2
#
# Processing slice G49
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G7', 'G11', 'G12', 'G32', 'G33']...
# Mapped 12 nodes out of 12 influence nodes
# Extended to 749 nodes (from 12 primary inputs)
# Subgraph has 926 edges
# ✓ Processed slice 'G49' with 749 nodes, class: 2
#
# Processing slice G50
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G5', 'G7', 'G9', 'G11', 'G12']...
# Mapped 27 nodes out of 27 influence nodes
# Extended to 1020 nodes (from 27 primary inputs)
# Subgraph has 1295 edges
# ✓ Processed slice 'G50' with 1020 nodes, class: 2
#
# Processing slice G51
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G5', 'G7', 'G11', 'G12', 'G15']...
# Mapped 20 nodes out of 20 influence nodes
# Extended to 942 nodes (from 20 primary inputs)
# Subgraph has 1182 edges
# ✓ Processed slice 'G51' with 942 nodes, class: 0
#
# Processing slice G52
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G5', 'G7', 'G9', 'G11', 'G12']...
# Mapped 25 nodes out of 25 influence nodes
# Extended to 1007 nodes (from 25 primary inputs)
# Subgraph has 1270 edges
# ✓ Processed slice 'G52' with 1007 nodes, class: 0
#
# Processing slice G53
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G5', 'G7', 'G8', 'G32']...
# Mapped 12 nodes out of 12 influence nodes
# Extended to 700 nodes (from 12 primary inputs)
# Subgraph has 836 edges
# ✓ Processed slice 'G53' with 700 nodes, class: 0
#
# Processing slice G54
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G7', 'G32', 'G33', 'G34', 'G35']...
# Mapped 10 nodes out of 10 influence nodes
# Extended to 691 nodes (from 10 primary inputs)
# Subgraph has 839 edges
# ✓ Processed slice 'G54' with 691 nodes, class: 2
#
# Processing slice G55
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G7', 'G13', 'G32', 'G33', 'G34']...
# Mapped 11 nodes out of 11 influence nodes
# Extended to 716 nodes (from 11 primary inputs)
# Subgraph has 868 edges
# ✓ Processed slice 'G55' with 716 nodes, class: 2
#
# Processing slice G56
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G7', 'G33']...
# Mapped 2 nodes out of 2 influence nodes
# Extended to 34 nodes (from 2 primary inputs)
# Subgraph has 36 edges
# ✓ Processed slice 'G56' with 34 nodes, class: 2
#
# Processing slice G57
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G1', 'G2', 'G3', 'G4']...
# Mapped 17 nodes out of 17 influence nodes
# Extended to 840 nodes (from 17 primary inputs)
# Subgraph has 1061 edges
# ✓ Processed slice 'G57' with 840 nodes, class: 0
#
# Processing slice G58
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G1', 'G2', 'G3', 'G4']...
# Mapped 32 nodes out of 32 influence nodes
# Extended to 1113 nodes (from 32 primary inputs)
# Subgraph has 1432 edges
# ✓ Processed slice 'G58' with 1113 nodes, class: 2
#
# Processing slice G59
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G1', 'G2', 'G3', 'G4']...
# Mapped 34 nodes out of 34 influence nodes
# Extended to 1139 nodes (from 34 primary inputs)
# Subgraph has 1473 edges
# ✓ Processed slice 'G59' with 1139 nodes, class: 1
#
# Processing slice G60
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G1', 'G2', 'G3', 'G4']...
# Mapped 16 nodes out of 16 influence nodes
# Extended to 794 nodes (from 16 primary inputs)
# Subgraph has 992 edges
# ✓ Processed slice 'G60' with 794 nodes, class: 0
#
# Processing slice G61
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G5', 'G7', 'G9', 'G11']...
# Mapped 21 nodes out of 21 influence nodes
# Extended to 992 nodes (from 21 primary inputs)
# Subgraph has 1250 edges
# ✓ Processed slice 'G61' with 992 nodes, class: 1
#
# Processing slice G62
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G5', 'G6', 'G7', 'G32']...
# Mapped 13 nodes out of 13 influence nodes
# Extended to 779 nodes (from 13 primary inputs)
# Subgraph has 953 edges
# ✓ Processed slice 'G62' with 779 nodes, class: 2
#
# Processing slice G63
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G5', 'G7', 'G9', 'G11']...
# Mapped 20 nodes out of 20 influence nodes
# Extended to 969 nodes (from 20 primary inputs)
# Subgraph has 1217 edges
# ✓ Processed slice 'G63' with 969 nodes, class: 1
#
# Processing slice G64
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G1', 'G2', 'G3', 'G4']...
# Mapped 22 nodes out of 22 influence nodes
# Extended to 999 nodes (from 22 primary inputs)
# Subgraph has 1264 edges
# ✓ Processed slice 'G64' with 999 nodes, class: 2
#
# Processing slice G65
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G1', 'G2', 'G3', 'G4']...
# Mapped 34 nodes out of 34 influence nodes
# Extended to 1120 nodes (from 34 primary inputs)
# Subgraph has 1443 edges
# ✓ Processed slice 'G65' with 1120 nodes, class: 1
#
# Processing slice G66
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G1', 'G2', 'G3', 'G4']...
# Mapped 34 nodes out of 34 influence nodes
# Extended to 1120 nodes (from 34 primary inputs)
# Subgraph has 1443 edges
# ✓ Processed slice 'G66' with 1120 nodes, class: 0
#
# Processing slice G67
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G1', 'G2', 'G3', 'G4']...
# Mapped 15 nodes out of 15 influence nodes
# Extended to 782 nodes (from 15 primary inputs)
# Subgraph has 974 edges
# ✓ Processed slice 'G67' with 782 nodes, class: 0
#
# Processing slice G68
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G5', 'G7', 'G9', 'G11', 'G12']...
# Mapped 24 nodes out of 24 influence nodes
# Extended to 1001 nodes (from 24 primary inputs)
# Subgraph has 1270 edges
# ✓ Processed slice 'G68' with 1001 nodes, class: 0
#
# Processing slice G69
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G1', 'G2', 'G3', 'G4']...
# Mapped 17 nodes out of 17 influence nodes
# Extended to 792 nodes (from 17 primary inputs)
# Subgraph has 989 edges
# ✓ Processed slice 'G69' with 792 nodes, class: 0
#
# Processing slice G70
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G5', 'G7', 'G11', 'G12', 'G15']...
# Mapped 21 nodes out of 21 influence nodes
# Extended to 959 nodes (from 21 primary inputs)
# Subgraph has 1198 edges
# ✓ Processed slice 'G70' with 959 nodes, class: 0
#
# Processing slice G71
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G5', 'G7', 'G9', 'G10', 'G11']...
# Mapped 23 nodes out of 23 influence nodes
# Extended to 978 nodes (from 23 primary inputs)
# Subgraph has 1239 edges
# ✓ Processed slice 'G71' with 978 nodes, class: 0
#
# Processing slice G72
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G1', 'G2', 'G3', 'G4']...
# Mapped 28 nodes out of 28 influence nodes
# Extended to 1068 nodes (from 28 primary inputs)
# Subgraph has 1372 edges
# ✓ Processed slice 'G72' with 1068 nodes, class: 0
#
# Processing slice G73
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G7', 'G32', 'G33', 'G34', 'G35']...
# Mapped 10 nodes out of 10 influence nodes
# Extended to 691 nodes (from 10 primary inputs)
# Subgraph has 839 edges
# ✓ Processed slice 'G73' with 691 nodes, class: 0
#
# Processing slice G74
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G1', 'G2', 'G3', 'G4']...
# Mapped 37 nodes out of 37 influence nodes
# Extended to 1158 nodes (from 37 primary inputs)
# Subgraph has 1502 edges
# ✓ Processed slice 'G74' with 1158 nodes, class: 2
#
# Processing slice G75
# Analyzing influence DataFrame with columns: ['Input', ' Influence', ' Runtime']
# Found nodes in column 'Input': ['G0', 'G1', 'G2', 'G3', 'G4']...
# Mapped 25 nodes out of 25 influence nodes
# Extended to 1019 nodes (from 25 primary inputs)
# Subgraph has 1301 edges
# ✓ Processed slice 'G75' with 1019 nodes, class: 2
# Added 35 slices from seq
#
# ==================================================
# SUMMARY: Total data objects created: 602

# %%
if len(all_data) > 0:
    # Analyze classification distribution
    class_counts = analyze_classification_distribution(all_data)
        
    # Save processed data
    with open('processed_circuit_data_classification.pkl', 'wb') as f:
        pickle.dump(all_data, f)
        
    # Save metadata
    metadata = {
            'total_samples': len(all_data),
            'num_classes': len(class_counts),
            'class_distribution': class_counts,
            'circuits': list(set([data.circuit_name for data in all_data])),
            'feature_dimensions': all_data[0].x.shape[1],
            'sample_info': {
                'num_nodes_range': (min([data.num_nodes for data in all_data]), 
                                   max([data.num_nodes for data in all_data])),
                'input_count_range': (min([data.input_count for data in all_data]), 
                                     max([data.input_count for data in all_data]))
            }
        }
        
    with open('classification_metadata.pkl', 'wb') as f:
        pickle.dump(metadata, f)
        
    print(f"\n✓ Saved {len(all_data)} processed data objects to 'processed_circuit_data_classification.pkl'")
    print(f"✓ Saved metadata to 'classification_metadata.pkl'")
    print(f"✓ Feature dimensions: {metadata['feature_dimensions']}")
    print(f"✓ Number of classes: {metadata['num_classes']}")
    print("Data preprocessing for classification complete!")
        
else:
    print("No data loaded. Please check your file paths and structure.")
# Out:
# Classification Distribution:
# Class 0: 46 samples (7.6%)
# Class 1: 30 samples (5.0%)
# Class 2: 526 samples (87.4%)
#
# Ratio statistics:
# Min ratio: 0.000458
# Max ratio: 31904.000000
# Mean ratio: 1155.878816
#
# ✓ Saved 602 processed data objects to 'processed_circuit_data_classification.pkl'
# ✓ Saved metadata to 'classification_metadata.pkl'
# ✓ Feature dimensions: 13
# ✓ Number of classes: 3
# Data preprocessing for classification complete!
